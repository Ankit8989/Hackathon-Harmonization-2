# %%
import os

subscription_key = os.getenv("AZURE_OPENAI_API_KEY", "")

# %%
import os
from openai import AzureOpenAI

subscription_key = os.getenv("AZURE_OPENAI_API_KEY", "")

client = AzureOpenAI(
    api_version="2024-12-01-preview",
    azure_endpoint="https://ankit-azure-2.openai.azure.com/",
    api_key=subscription_key,
)

# %%
import os
from openai import AzureOpenAI

endpoint = "https://ankit-mkozog2d-eastus2.cognitiveservices.azure.com/"
model_name = "gpt-5.2-chat"
deployment = "gpt-5.2-chat"

subscription_key = os.getenv("AZURE_OPENAI_API_KEY", "")
api_version = "2024-12-01-preview"

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "I am going to Paris, what should I see?",
        },
        {
            "role": "assistant",
            "content": "Paris, the capital of France, is known for its stunning architecture, art museums, historical landmarks, and romantic atmosphere. Here are some of the top attractions to see in Paris:\n\n1. The Eiffel Tower: The iconic Eiffel Tower is one of the most recognizable landmarks in the world and offers breathtaking views of the city.\n2. The Louvre Museum: The Louvre is one of the worlds largest and most famous museums, housing an impressive collection of art and artifacts, including the Mona Lisa.\n3. Notre-Dame Cathedral: This beautiful cathedral is one of the most famous landmarks in Paris and is known for its Gothic architecture and stunning stained glass windows.\n\nThese are just a few of the many attractions that Paris has to offer. With so much to see and do, its no wonder that Paris is one of the most popular tourist destinations in the world.",
        },
        {
            "role": "user",
            "content": "What is so great about #1?",
        }
    ],
    max_completion_tokens =16384,
    model=deployment
)

print(response.choices[0].message.content)
# Out:
# The Eiffel Tower is special for several reasons, beyond just being a famous photo spot:
#
# **1. Iconic design and history**
# Built in 1889 for the World’s Fair, it was an engineering marvel of its time. Gustave Eiffel’s iron lattice design was controversial at first, but it eventually became the symbol of Paris and even of France itself.
#
# **2. Incredible views**
# From the top (or even the second floor), you get sweeping views over Paris: the Seine winding through the city, landmarks like the Louvre, Sacré‑Cœur, and on clear days, far beyond the city limits. It’s especially beautiful at sunset.
#
# **3. Different experiences at different levels**
# - The **esplanade** lets you appreciate its massive scale up close.
# - The **second floor** offers the best balance of height and detail for views.
# - The **summit** gives a true “wow” moment and a sense of being above the city.
#
# **4. Nighttime magic**
# Every evening, the tower sparkles for five minutes at the top of each hour after dark. It’s a uniquely Parisian experience and very romantic.
#
# **5. Location and atmosphere**
# It sits along the Seine near parks like the Champ de Mars and Trocadéro, making it easy to combine with a picnic, a riverside walk, or photos from multiple viewpoints.
#
# Even if you don’t go up, seeing the Eiffel Tower in different contexts—day, night, from across the river, or framed by Parisian streets—helps you understand why it’s so beloved.
